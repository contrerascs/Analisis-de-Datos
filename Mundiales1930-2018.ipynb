# %% [markdown]
# ## Extracción de Datos con BeautifulSoup

# %%
from bs4 import BeautifulSoup
import requests 
web = 'https://en.wikipedia.org/wiki/2014_FIFA_World_Cup'
years = [1930, 1934, 1950, 1954, 1958, 1962, 1966, 1970, 1974,
         1978, 1982, 1986, 1990, 1994, 1998, 2002, 2010, 2014,
         2018]
#Usamos 'requests' para obtener una respuesta de la página web
response = requests.get(web)
content = response.text
#Usamos BeautifulSoup para leer de mejor manera la información que obtuvimos como respuesta
soup = BeautifulSoup(content, 'lxml')

# %%
from PIL import Image 
img = Image.open('Imagenes Explicativas/Img_1.png')    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1150x152>

# %%
#Metodo 'find_all' para inspeccionar la página
#Notamos que todos los partidos vienen en la clase 'fooballbox'
matches = soup.find_all('div',class_='footballbox')
#Método 'find_all' nos devuelve una lista
for match in matches:
    print(match.find('th',class_='fhome').get_text())
    print(match.find('th',class_='fscore').get_text())
    print(match.find('th',class_='faway').get_text())
# Out:
# Brazil
# 3–1
#  Croatia
# Mexico
# 1–0
#  Cameroon
# Brazil
# 0–0
#  Mexico
# Cameroon
# 0–4
#  Croatia
# Cameroon
# 1–4
#  Brazil
# Croatia
# 1–3
#  Mexico
# Spain
# 1–5
#  Netherlands
# Chile
# 3–1
#  Australia
# Australia
# 2–3
#  Netherlands
# Spain
# 0–2
#  Chile
# Australia
# 0–3
#  Spain
# Netherlands
# 2–0
#  Chile
# Colombia
# 3–0
#  Greece
# Ivory Coast
# 2–1
#  Japan
# Colombia
# 2–1
#  Ivory Coast
# Japan
# 0–0
#  Greece
# Japan
# 1–4
#  Colombia
# Greece
# 2–1
#  Ivory Coast
# Uruguay
# 1–3
#  Costa Rica
# England
# 1–2
#  Italy
# Uruguay
# 2–1
#  England
# Italy
# 0–1
#  Costa Rica
# Italy
# 0–1
#  Uruguay
# Costa Rica
# 0–0
#  England
# Switzerland
# 2–1
#  Ecuador
# France
# 3–0
#  Honduras
# Switzerland
# 2–5
#  France
# Honduras
# 1–2
#  Ecuador
# Honduras
# 0–3
#   Switzerland
# Ecuador
# 0–0
#  France
# Argentina
# 2–1
#  Bosnia and Herzegovina
# Iran
# 0–0
#  Nigeria
# Argentina
# 1–0
#  Iran
# Nigeria
# 1–0
#  Bosnia and Herzegovina
# Nigeria
# 2–3
#  Argentina
# Bosnia and Herzegovina
# 3–1
#  Iran
# Germany
# 4–0
#  Portugal
# Ghana
# 1–2
#  United States
# Germany
# 2–2
#  Ghana
# United States
# 2–2
#  Portugal
# United States
# 0–1
#  Germany
# Portugal
# 2–1
#  Ghana
# Belgium
# 2–1
#  Algeria
# Russia
# 1–1
#  South Korea
# Belgium
# 1–0
#  Russia
# South Korea
# 2–4
#  Algeria
# South Korea
# 0–1
#  Belgium
# Algeria
# 1–1
#  Russia
# Brazil
# 1–1 (a.e.t.)
#  Chile
# Colombia
# 2–0
#  Uruguay
# Netherlands
# 2–1
#  Mexico
# Costa Rica
# 1–1 (a.e.t.)
#  Greece
# France
# 2–0
#  Nigeria
# Germany
# 2–1 (a.e.t.)
#  Algeria
# Argentina
# 1–0 (a.e.t.)
#   Switzerland
# Belgium
# 2–1 (a.e.t.)
#  United States
# France
# 0–1
#  Germany
# Brazil
# 2–1
#  Colombia
# Argentina
# 1–0
#  Belgium
# Netherlands
# 0–0 (a.e.t.)
#  Costa Rica
# Brazil
# 1–7
#  Germany
# Netherlands
# 0–0 (a.e.t.)
#  Argentina
# Brazil
# 0–3
#  Netherlands
# Germany
# 1–0 (a.e.t.)
#  Argentina
